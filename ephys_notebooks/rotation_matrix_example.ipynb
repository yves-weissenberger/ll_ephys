# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
get_T = lambda x: np.array([[np.cos(x),-np.sin(x)],
                            [np.sin(x),np.cos(x)]])

# %%
T
# Out:
# array([[ 0.8660254, -0.5      ],
#        [ 0.5      ,  0.8660254]])

# %%
T = get_T(np.pi/6)

# %%
res = [np.array([.1,0])]
for i in range(50):
    res.append(T.dot(res[-1]))

# %%
plt.plot(np.array(res)[:,1])
plt.plot(np.array(res)[:,0])

# %%
T.dot(res[-1])
# Out:
# array([[ 0.8660254,  0.5      ],
#        [-0.5      ,  0.8660254]])
